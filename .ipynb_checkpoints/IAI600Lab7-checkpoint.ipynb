# %%
# !pip install keras-tuner
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 4.0 MB/s eta 0:00:00
# ...

# %%
# Import necessary libraries
import tensorflow as tf
from tensorflow import keras
import keras_tuner as kt
from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping

# %% [markdown]
# ### Prepare the dataset

# %%
# Prepare the MNIST dataset
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split

mnist = fetch_openml('mnist_784', version=1, as_frame=False)
X, y = mnist['data'], mnist['target']
X_train, X_test, y_train, y_test = X[:60000], X[60000:], y[:60000], y[60000:]
y_train = y_train.astype(int)
y_test = y_test.astype(int)
X_train = X_train.reshape((60000, 28, 28))
X_test = X_test.reshape((10000, 28, 28))

# Perform a stratified split to create a validation set from the training data
X_train_part, X_val, y_train_part, y_val = train_test_split(
    X_train, y_train, test_size=0.1, stratify=y_train, random_state=42
)

# %% [markdown]
# ### Define the model building function for Keras Tuner

# %%
import keras
import keras_tuner as kt

def build_model(hp):
    model = keras.models.Sequential()
    model.add(keras.layers.Flatten(input_shape=[28, 28]))

    # Tune the number of hidden layers and units in each layer
    for i in range(hp.Int('num_layers', 2, 5)):  # Tuning between 2 to 5 hidden layers
        model.add(keras.layers.Dense(
            units=hp.Int('units_' + str(i), min_value=64, max_value=512, step=64),
            activation='relu'
        ))
        # Add dropout for regularization
        model.add(keras.layers.Dropout(rate=hp.Choice('dropout_rate_' + str(i), [0.2, 0.3, 0.4])))

    # Output layer with softmax activation for multi-class classification
    model.add(keras.layers.Dense(10, activation='softmax'))

    # Compile the model with a tuned learning rate
    model.compile(
        optimizer=keras.optimizers.Adam(
            hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])
        ),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    # Add batch_size and epochs as hyperparameters
    hp_batch_size = hp.Choice('batch_size', values=[16, 32, 64])
    hp_epochs = hp.Int('epochs_size', min_value=10, max_value=30, step=10)

    return model

# %% [markdown]
# ### Fine tuning the model

# %%
# Instantiate the Keras Tuner for hyperparameter search
tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=5,
    executions_per_trial=3,
    directory='my_dir',
    project_name='mnist_keras_tuner'
)

# Start the search
tuner.search(
    X_train_part, y_train_part,
    validation_data=(X_val, y_val),
)
# Out:
# Trial 5 Complete [00h 00m 34s]
# val_accuracy: 0.14827777445316315
#
# Best val_accuracy So Far: 0.9265555540720621
# Total elapsed time: 00h 03m 52s

# %% [markdown]
# ### Training the model with the best hyperparameters found

# %%
# Get the best hyperparameters and build the model
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
model = tuner.hypermodel.build(best_hps)

# Retrieve the best epochs and batch sizes
best_epochs = best_hps.get('epochs_size')
best_batch_size = best_hps.get('batch_size')


# Early stopping callback for final training (optional, if concerned about overfitting)
early_stopping = EarlyStopping(
    monitor="accuracy",  # Now monitoring training accuracy instead
    patience=7,
    restore_best_weights=True
)

# Train the model on the full training set without specifying validation data
history = model.fit(
    X_train, y_train,
    epochs=best_epochs,
    batch_size=best_batch_size,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.6019 - loss: 5.3327
# Epoch 2/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8843 - loss: 0.4181
# Epoch 3/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9209 - loss: 0.2940
# Epoch 4/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9317 - loss: 0.2572
# Epoch 5/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9385 - loss: 0.2356
# Epoch 6/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9453 - loss: 0.2089
# Epoch 7/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9454 - loss: 0.2121
# Epoch 8/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9490 - loss: 0.2068
# Epoch 9/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9513 - loss: 0.1891
# Epoch 10/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9547 - loss: 0.1903

# %% [markdown]
# ## Evaluating the model

# %% [markdown]
# ### Accuracy

# %%
# Evaluate the model on the separate test set to get final performance metrics
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9713 - loss: 0.1356
# Test accuracy: 0.9740999937057495

# %% [markdown]
# ### Confusion Matrix

# %%
def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in np.ndindex(cm.shape):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# Confusion Matrix Plotting
y_pred = model.predict(X_test).argmax(axis=1)
conf_matrix = confusion_matrix(y_test, y_pred)


plot_confusion_matrix(conf_matrix, classes=range(10))
plt.show()

# Plot training and validation accuracy over epochs
import pandas as pd
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
